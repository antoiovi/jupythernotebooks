# %% [markdown]
# # Scaricare i dati da yahoo con pandas_datareader oppure yfinance
# In questo notebook utilizziamo due  librerie  per scaricare i dati finanziari da Yahoo Finance:
# *  ***pandas_datareader***
# * ***yfinance***
#
# <p>
#
#     1- Scaricare il file  https://pypi.org/project/yfinance/#files
#
#     2 - Installare
#
#         $ python3 -m pip install ~/Downloads/yfinance-0.1.59.tar.gz
# </p>

# %% [markdown]
# # pandas_datareader
#
# https://pandas-datareader.readthedocs.io/en/latest/index.html
#
# ```bash
#  pip install --upgrade pandas-datareader
# ```
#
# Prima di tutto stampiamo la versione Python utilizzata in questi esempi :

# %%
import sys
import pandas_datareader
import pandas as pd
print("Python version   : {}".format(sys.version))
print("pandas_datareader version : {}".format(pandas_datareader.__version__))
print("pandas version :   {}".format(pd.__version__))
# Out:
# Python version   : 3.7.7 (default, May  7 2020, 21:25:33)
# [GCC 7.3.0]
# pandas_datareader version : 0.10.0
# pandas version :   1.0.3

# %%
from pandas_datareader import data

# %%
aapl = data.DataReader("AAPL", 
                       start='2020-01-1', 
                       end='2020-08-18', 
                       data_source='yahoo')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d3ba11a03709> in <module>
#       1 # Only get the adjusted close.
# ----> 2 aapl = data.DataReader("AAPL",
#       3                        start='2020-01-1',
#       4                        end='2020-06-30',
#       5                        data_source='yahoo')
#
# NameError: name 'data' is not defined

# %%
aapl.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  74.096443
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.376083
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  73.960770
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.612930
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.797081

# %%
aapl['Adj Close'].plot()

# %% [markdown]
# ## Importiamo un titolo dalla borsa di Milano

# %%
# Importiamo solo la chiusura
fca = data.DataReader("ses.MI", 
                       start='2019-1-1', 
                       end='2021-08-18', 
                       data_source='yahoo')

# %%
fca.head()
# Out:
#               High     Low    Open   Close   Volume  Adj Close
# Date
# 2021-01-04  3.6840  3.4000  3.4000  3.5560  1750687     3.5560
# 2021-01-05  3.6600  3.5230  3.5995  3.6060   894036     3.6060
# 2021-01-06  3.8000  3.2700  3.5985  3.3675  1440138     3.3675
# 2021-01-07  3.5400  3.3825  3.4905  3.5065   486785     3.5065
# 2021-01-08  3.3475  2.9105  3.3175  2.9730  2804416     2.9730

# %%
fca['Adj Close'].plot()

# %% [markdown]
# # yfinance
#
# https://pypi.org/project/yfinance/
#
# ```bash
#  python3 -m pip install ~/Downloads/yfinance-0.1.63.tar.gz
# ```

# %%
import sys
import pandas as pd
import yfinance as yf

print("Python version   : {}".format(sys.version))
print("pandas version :   {}".format(pd.__version__))
print("yfinance  version : {}".format(yf.__version__))
# Out:
# Python version   : 3.7.7 (default, May  7 2020, 21:25:33)
# [GCC 7.3.0]
# pandas version :   1.0.3
# yfinance  version : 0.1.63

# %%
import yfinance as yf

W3SIL = yf.Ticker("3SIL.MI")
W3SIL = W3SIL.history(period="max")

# %%
W3SIL.head()
# Out:
#               Open    High     Low   Close  Volume  Dividends  Stock Splits
# Date
# 2013-12-02  11.300  11.320  10.950  10.800    1475          0             0
# 2013-12-03  10.095  10.180  10.095  10.265    4699          0             0
# 2013-12-04  10.000  10.665   9.990  10.575    1030          0             0
# 2013-12-05  10.725  10.825  10.510  10.845    5500          0             0
# 2013-12-06  10.745  10.745  10.745  10.820    2000          0             0

# %%
df=yf.download("3SIL.MI",period="1mo",interval="15m")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                              Open    High     Low   Close  Adj Close  Volume
# Datetime
# 2021-08-23 09:00:00+02:00  1.7450  1.7450  1.7414  1.7450     1.7450    3778
# 2021-08-23 09:15:00+02:00  1.7460  1.7460  1.7368  1.7400     1.7400   36259
# 2021-08-23 09:45:00+02:00  1.7540  1.7540  1.7540  1.7540     1.7540     843
# 2021-08-23 10:00:00+02:00  1.7566  1.7568  1.7566  1.7568     1.7568   35000
# 2021-08-23 10:15:00+02:00  1.7600  1.7712  1.7600  1.7700     1.7700   48400
# ...                           ...     ...     ...     ...        ...     ...
# 2021-09-20 16:30:00+02:00  1.5270  1.5350  1.5270  1.5350     1.5350    3300
# 2021-09-20 16:45:00+02:00  1.5312  1.5500  1.5312  1.5312     1.5312   28198
# 2021-09-20 17:00:00+02:00  1.5350  1.5400  1.5262  1.5262     1.5262  202970
# 2021-09-20 17:15:00+02:00  1.5272  1.5272  1.5206  1.5206     1.5206   53820
# 2021-09-20 17:30:00+02:00  1.5208  1.5208  1.5208  1.5208     1.5208       0
#
# [607 rows x 6 columns]

# %%
df=yf.download("USDEUR=X",period="1mo",interval="15m")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                              Open    High     Low   Close  Adj Close  Volume
# Datetime
# 2021-08-18 00:00:00+01:00  0.8540  0.8540  0.8537  0.8539     0.8539       0
# 2021-08-18 00:15:00+01:00  0.8539  0.8540  0.8536  0.8538     0.8538       0
# 2021-08-18 00:30:00+01:00  0.8538  0.8539  0.8535  0.8537     0.8537       0
# 2021-08-18 00:45:00+01:00  0.8538  0.8538  0.8536  0.8538     0.8538       0
# 2021-08-18 01:00:00+01:00  0.8538  0.8539  0.8533  0.8533     0.8533       0
# ...                           ...     ...     ...     ...        ...     ...
# 2021-09-17 21:00:00+01:00  0.8523  0.8525  0.8522  0.8525     0.8525       0
# 2021-09-17 21:30:00+01:00  0.8525  0.8526  0.8525  0.8526     0.8526       0
# 2021-09-17 21:45:00+01:00  0.8526  0.8527  0.8525  0.8526     0.8526       0
# 2021-09-17 22:00:00+01:00  0.8525  0.8525  0.8524  0.8524     0.8524       0
# 2021-09-17 22:15:00+01:00  0.8524  0.8524  0.8524  0.8524     0.8524       0
#
# [1948 rows x 6 columns]
